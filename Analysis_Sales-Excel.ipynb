# %% [markdown]
# # <font color='blue'>Analysis Sales Excel</font>

# %% [markdown]
# #### Sales analysis in Excel report

# %% [markdown]
# ________________________

# %% [markdown]
# ![title](image/wallpaper.PNG)

# %% [markdown]
# ___________

# %% [markdown]
#     Some of the Questions not included in the report, answered in each excel worksheet:
#
#
#     - Determine the total increase in sales
#     - Determine the new total Payroll
#     - How many employees received a 3.50% raise?
#     - Representatives with sales below $100.00 per day will be recommended for a development plan ?

# %% [markdown]
# ___

# %% [markdown]
# **Points of Analysis in the report :**
#
#      - Daily sales figures
#      - Sales performance per representative
#      - Percentage contribution per representative

# %% [markdown]
# # <font color ='grey'>**Sales Report**</font>

# %% [markdown]
# ![title](image/Image_report.PNG)

# %% [markdown]
# _Take a look here_: [Code & Excel](https://github.com/ElvisRock/Analysis_Sales-Excel)

# %% [markdown]
# ### Thank you
#
# Author: [Elvis](http://elvisrock.github.io/)
